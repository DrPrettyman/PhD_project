# %%
import numpy as np
from thesisfigures import onedimensionalmethods

# %%
onedimensionalmethods.fig08()
# Out:
# Setting parameters...
# generating time series...
# Calculating the expected power spectra...
# calculating PSD for white noise...
# calculating PSD for random walk...
# calculating PSD for combined series...
# Plotting results...
# Drawing figure with 1 subplots with layout [[0]]
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not currently support the selected font.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-dfec54671598> in <module>
# ----> 1 onedimensionalmethods.fig08()
#
# ...
